# %%
from googleapiclient.discovery import build

api_key = "AIzaSyBjTqOUFQeKdd17kMAgp5CuAUUedMZXWLU"
youtube = build("youtube", "v3", developerKey=api_key)

request = youtube.channels().list(
    part="statistics",
    id="UCX6OQ3DkcsbYNE6H8uQQuVA"   # yaha apna channel ID daalo
)
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': '_LUWzr3gaz3opQLrhFxCN_4-w8w', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'kVYyT3TSqiBR_oWFPz2ccLiJB3w', 'id': 'UCX6OQ3DkcsbYNE6H8uQQuVA', 'statistics': {'viewCount': '101177881399', 'subscriberCount': '451000000', 'hiddenSubscriberCount': False, 'videoCount': '920'}}]}

# %%
video_ids = []

request = youtube.search().list(
    part="snippet",
    channelId="UCX6OQ3DkcsbYNE6H8uQQuVA",
    maxResults=50,
    order="date",
    type="video"   # IMPORTANT: only videos return videoId
)
response = request.execute()

for item in response.get("items", []):
    video_id = item["id"].get("videoId")
    if video_id:
        video_ids.append(video_id)

print(video_ids)
# Out:
# ['WROMyJAJmp4', 'tAwzBYE18Us', 'LyFMbY-c_Lc', '26QQE7EsnLA', 'JgJrQnDIRgg', 'oiZvK6MY7tI', 'F0OkwXKcPSE', 'TDv56whosPQ', 'R_BmT1OJw98', 'V6In4tmd-w8', 'c2ukL_zjFCk', 'DZIASl9q90s', '3dxksf0CzS8', 'Tbn4cYCaZCk', 'zajUgQLviwk', 'nAiKLoCP-kU', 'NDsO1LT_0lw', 'sF5LYGgKbUA', 'gs8qfL9PNac', 'SWc8fI_9iqA', 'Xj0Jtjg3lHQ', 'bn0Kh9c4Zv4', '8krJy31Diow', '8bTQMDM4qvY', 'snUyLbGx6U4', 'Pv0iVoSZzN8', 'CWbV3NItSdY', '7ESeQBeikKs', 'c0v8OPItCOg', '3ryID_SwU5E', 'IemzxkkzI5s', '3OFj6l2tQ9s', 'J_z-W4UVHkw', 'yhB3BgJyGl8', 'ooAwCOP67GQ', 'lglIQkCHO0g', '7IKab3HcfFk', 'h5NvTTOlOtI', 'se50viFJ0AQ', 'kX3nB4PpJko', 'iogcY_4xGjo', 'tVWWp1PqDus', 'Hwybp38GnZw', 'zxYjTTXc-J8', 'ktyJIj6i4Qw', 'nM89Wl03Q4g', 'TQHEJj68Jew', 'vp5sSqyZ5Go', 'Rj_vssRaZlQ', 'YQDDm9HLkV4']

# %%
import pandas as pd

all_data = []

for vid in video_ids:
    req = youtube.videos().list(
        part="statistics,snippet",
        id=vid
    )
    res = req.execute()

    for item in res["items"]:
        data = {
            "video_id": vid,
            "title": item["snippet"]["title"],
            "published": item["snippet"]["publishedAt"],
            "views": item["statistics"].get("viewCount", 0),
            "likes": item["statistics"].get("likeCount", 0),
            "comments": item["statistics"].get("commentCount", 0)
        }
        all_data.append(data)

df = pd.DataFrame(all_data)
df
# Out:
#        video_id                                              title  \
# 0   WROMyJAJmp4                           Can I Beat An F1 Driver?
# 1   tAwzBYE18Us                                How I Became MrBeef
# 2   LyFMbY-c_Lc                                 I Raced Noah Lyles
# 3   26QQE7EsnLA                              MrBeast Lab Disaster!
# 4   JgJrQnDIRgg            First to Answer the Phone, Wins $10,000
# 5   oiZvK6MY7tI                          Call Your Ex, Win $10,000
# 6   F0OkwXKcPSE                                  Hi Me In 10 Years
# 7   TDv56whosPQ           Survive 100 Days In Prison, Win $500,000
# 8   R_BmT1OJw98                   Every YouTube Play Button I Have
# 9   V6In4tmd-w8                                  $1 vs $25,000 VFX
# 10  c2ukL_zjFCk                                Extreme Helmet Game
# 11  DZIASl9q90s                          Beat Neymar, Win $500,000
# 12  3dxksf0CzS8                            World’s Fastest Robbers
# 13  Tbn4cYCaZCk                        Drift This Car, Win $10,000
# 14  zajUgQLviwk           Last to Leave Their Circle Wins $500,000
# 15  nAiKLoCP-kU                       Reach the Money, Win $10,000
# 16  NDsO1LT_0lw             I Spent 100 Hours Inside The Pyramids!
# 17  sF5LYGgKbUA              Every Minute One Person Is Eliminated
# 18  gs8qfL9PNac                  2,000 People Fight For $5,000,000
# 19  SWc8fI_9iqA                     Ronaldo Teaches Me How To SIUU
# 20  Xj0Jtjg3lHQ                        $1 vs $500,000 Experiences!
# 21  bn0Kh9c4Zv4               7 Days Exploring An Underground City
# 22  8krJy31Diow                     Holding Bigger And Bigger Dogs
# 23  8bTQMDM4qvY                   Spot The Fake Animal For $10,000
# 24  snUyLbGx6U4                Buy Feastables, Win Unlimited Money
# 25  Pv0iVoSZzN8              In 10 Minutes This Room Will Explode!
# 26  CWbV3NItSdY                       The World's Fastest Cleaners
# 27  7ESeQBeikKs                          Protect $500,000 Keep It!
# 28  c0v8OPItCOg                              $100,000,000 Bathroom
# 29  3ryID_SwU5E                          $1 vs $100,000,000 House!
# 30  IemzxkkzI5s             I Tipped A Pizza Delivery Driver A Car
# 31  3OFj6l2tQ9s                       World's Most Dangerous Trap!
# 32  J_z-W4UVHkw        Every Country On Earth Fights For $250,000!
# 33  yhB3BgJyGl8                             7 Days Stranded At Sea
# 34  ooAwCOP67GQ                             Do Pawnshops Scam You?
# 35  lglIQkCHO0g                     Do Men Lie About Their Height?
# 36  7IKab3HcfFk                  I Survived 50 Hours In Antarctica
# 37  h5NvTTOlOtI                     Hydraulic Press Vs Lamborghini
# 38  se50viFJ0AQ             Would You Fly To Paris For A Baguette?
# 39  kX3nB4PpJko                11 YouTubers Fight For Private Jet!
# 40  iogcY_4xGjo                       $1 vs $1,000,000 Hotel Room!
# 41  tVWWp1PqDus                 100 Boys Vs 100 Girls For $500,000
# 42  Hwybp38GnZw           I Built Willy Wonka's Chocolate Factory!
# 43  zxYjTTXc-J8                 Last To Leave Circle Wins $500,000
# 44  ktyJIj6i4Qw           If You Can Carry $1,000,000 You Keep It!
# 45  nM89Wl03Q4g   I Survived 50 Hours In A Maximum Security Prison
# 46  TQHEJj68Jew               I Got Hunted By A Real Bounty Hunter
# 47  vp5sSqyZ5Go  I Filled My Brother’s House With Slime & Bough...
# 48  Rj_vssRaZlQ           I Ate The World’s Largest Slice Of Pizza
# 49  YQDDm9HLkV4               I Adopted EVERY Dog In A Dog Shelter
#
